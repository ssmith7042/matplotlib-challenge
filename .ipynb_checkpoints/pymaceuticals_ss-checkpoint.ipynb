# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# As shown in the summary statistics table and visualized by the box plots below, Capomulin and Ramicane were the most effective treatments, achieving the lowest tumor volumes.  The final tumor volume for these treatment groups showed similar outcomes, with Ramicane having slightly better results.  The summary statistics table suggests that all of the other treatment regimens performed similarly and notably worse than Capomulin and Ramicane based on the measure of their groups' tumor volumes.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# %%
# Study data files
mouse_metadata_path = "Mouse_metadata.csv"
study_results_path = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame

combined_df=mouse_metadata.merge(study_results, how='left', on='Mouse ID')
combined_df
# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
NumberOfMice=len(pd.unique(combined_df['Mouse ID']))
NumberOfMice
len(combined_df)
# Out:
# 1893

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_df.loc[combined_df.duplicated(['Mouse ID','Timepoint'], keep=False)==True]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned=combined_df[combined_df['Mouse ID']!='g989']
cleaned
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
len(cleaned)
# Out:
# 1880

# %% [markdown]
# ## Summary Statistics

# %%
summary_statistics=cleaned.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['var','median', 'mean','std','sem'])
summary_statistics
# Out:
#              Tumor Volume (mm3)
#                             var     median       mean       std       sem
# Drug Regimen
# Capomulin             24.947764  41.557809  40.675741  4.994774  0.329346
# Ceftamin              39.290177  51.776157  52.591172  6.268188  0.469821
# Infubinol             43.128684  51.820584  52.884795  6.567243  0.492236
# Ketapril              68.553577  53.698743  55.235638  8.279709  0.603860
# Naftisol              66.173479  52.509285  54.331565  8.134708  0.596466
# Placebo               61.168083  52.288934  54.033581  7.821003  0.581331
# Propriva              43.852013  50.446266  52.320930  6.622085  0.544332
# Ramicane              23.486704  40.673236  40.216745  4.846308  0.320955
# Stelasyn              59.450562  52.431737  54.233149  7.710419  0.573111
# Zoniferol             48.533355  51.818479  53.236507  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
bar_xy=cleaned['Drug Regimen'].value_counts()
bar_xy.plot(kind='bar', figsize=(6,3))
plt.ylabel("Number of Rows")
# Out:
# Text(0, 0.5, 'Number of Rows')

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
x_axis=np.arange(len(bar_xy))
tick_locations=[value for value in x_axis]
plt.bar(x_axis,cleaned['Drug Regimen'].value_counts(), color='r', alpha=0.5, align='center')
plt.xticks(tick_locations, summary_statistics.index.tolist(), rotation='vertical')
plt.ylabel("Number of rows of data")
plt.show()

# %%
sex_counts = cleaned['Sex'].value_counts()
sex_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title("Mouse Sex Breakdown")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
fig, ax = plt.subplots()
labels=['Male','Female']
ax.pie(sex_counts,labels=labels, autopct='%1.1f%%')
plt.title("Mouse Sex Breakdown")
# Out:
# Text(0.5, 1.0, 'Mouse Sex Breakdown')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
last_measure=cleaned.groupby('Mouse ID').max('Timepoint')['Timepoint']
last_measure=last_measure.reset_index()
last_measure
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 243     z435         10
# 244     z578         45
# 245     z581         45
# 246     z795         45
# 247     z969         45
#
# [248 rows x 2 columns]

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
merge_last=last_measure.merge(cleaned, on=['Mouse ID','Timepoint'],how='left')
merge_last
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels): Capomulin, Ramicane, Infubinol, and Ceftamin
treatments=['Capomulin','Ramicane','Infubinol','Ceftamin']
# Create empty list to fill with tumor vol data (for plotting)
tumor_vols=[]

for treatment in treatments:
    
    last_tv=merge_last.loc[merge_last['Drug Regimen']==treatment]['Tumor Volume (mm3)']
    quartiles=last_tv.quantile([.25,.5,.75])
    lowerq=quartiles[0.25]
    upperq=quartiles[0.75]
    iqr=upperq-lowerq
    lower_bound=lowerq-(1.5*iqr)
    upper_bound=upperq+(1.5*iqr)
    outliers=[]
    for measure in last_tv:
        if measure<lower_bound or measure>upper_bound:
            outliers.append(measure)
    print(f"{treatment} potential outliers are {outliers}")
    print(f"{treatment} interquartile range is {iqr}")
# Out:
# Capomulin potential outliers are []
# Capomulin interquartile range is 7.781863460000004
# Ramicane potential outliers are []
# Ramicane interquartile range is 9.098536719999998
# Infubinol potential outliers are [36.3213458]
# Infubinol interquartile range is 11.477135160000003
# Ceftamin potential outliers are []
# Ceftamin interquartile range is 15.577752179999997

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
capomulin=merge_last.loc[(merge_last['Drug Regimen']=='Capomulin'),:]
ramicane=merge_last.loc[(merge_last['Drug Regimen']=='Ramicane'),:]
infubinol=merge_last.loc[(merge_last['Drug Regimen']=='Infubinol'),:]
ceftamin=merge_last.loc[(merge_last['Drug Regimen']=='Ceftamin'),:]

fig1, ax1 = plt.subplots()
ax1.set_title('Capomulin Outcomes')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(capomulin['Tumor Volume (mm3)'])

fig2, ax2 = plt.subplots()
ax2.set_title('Ramicane Outcomes')
ax2.set_ylabel('Tumor Volume (mm3)')
ax2.boxplot(ramicane['Tumor Volume (mm3)'])

fig3, ax3 = plt.subplots()
ax3.set_title('Infubinol Outcomes')
ax3.set_ylabel('Tumor Volume (mm3)')
ax3.boxplot(infubinol['Tumor Volume (mm3)'])

fig4, ax4 = plt.subplots()
ax4.set_title('Ceftamin Outcomes')
ax4.set_ylabel('Tumor Volume (mm3)')
ax4.boxplot(ceftamin['Tumor Volume (mm3)'])
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
isolate_957=cleaned.loc[cleaned['Mouse ID']=='m957']
plt.plot(isolate_957.Timepoint.tolist(),isolate_957['Tumor Volume (mm3)'], color='red', label='m957')
plt.title("M957 Treatment")
plt.xlabel("Timepoints")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
weight=capomulin['Weight (g)'].tolist()
tumor_volume=capomulin['Tumor Volume (mm3)'].tolist()
plt.scatter(weight, tumor_volume, marker='o', facecolors='red')
plt.title("Weight/Tumor Volume for Capomulin")
plt.xlabel("Weight (g)")
plt.ylabel("Tumor Volume")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
x_values = weight
y_values = tumor_volume
correlation=st.pearsonr(weight, tumor_volume)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
for x in x_values:
    regress_values = x * slope + intercept

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 11
#       8     regress_values = x * slope + intercept
#      10 plt.scatter(x_values,y_values)
# ---> 11 plt.plot(x_values,regress_values,"r-")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...
